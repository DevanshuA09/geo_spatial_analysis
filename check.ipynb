# %%
import pandas as pd

# %%
df = pd.read_csv('muis_complete_final.csv')
df.head()
# Out:
#   source                              place_id        name  outlet_name  \
# 0   muis  1eb5ea3a-9562-4e1f-a4ad-d444ba0f3acd  McDonald's          NaN
# 1   muis  1eb5ea3a-9562-4e1f-a4ad-d444ba0f3acd  McDonald's          NaN
# 2   muis  1eb5ea3a-9562-4e1f-a4ad-d444ba0f3acd  McDonald's          NaN
# 3   muis  1eb5ea3a-9562-4e1f-a4ad-d444ba0f3acd  McDonald's          NaN
# 4   muis  1eb5ea3a-9562-4e1f-a4ad-d444ba0f3acd  McDonald's          NaN
#
#                                              address  postal_code  latitude  \
# 0  9 TAMPINES AVENUE 2 #01-02 SHELL SERVICE STATI...       529731       NaN
# 1  600 HOUGANG AVENUE 3 #01-01 MOBIL SERVICE STAT...       538846       NaN
# 2     130 DUNEARN ROAD CALTEX SERVICE STATION 309436       309436       NaN
# 3  548 HAVELOCK ROAD SHELL SERVICE STATION, (Part...       169637       NaN
# 4  6 RAFFLES BOULEVARD #02-156/157/166 MARINA SQU...        39594       NaN
#
#    longitude     muis_halal_status  cuisine  website  phone  \
# ...

# %%
df.columns
# Out:
# Index(['source', 'place_id', 'name', 'outlet_name', 'address', 'postal_code',
#        'latitude', 'longitude', 'muis_halal_status', 'cuisine', 'website',
#        'phone', 'last_scraped', 'source_url', 'notes', 'certificate_number',
#        'type', 'scheme', 'sub_scheme'],
#       dtype='object')

# %%
df['scheme'].unique()
# Out:
# array([100, 200])

# %%
df['sub_scheme'].unique()
# Out:
# array([104, 106, 108, 103, 202, 201, 109, 101, 105, 102])

# %%
df['type'].unique()
# Out:
# array([0, 1])
